# %% [markdown]
# <a href="https://colab.research.google.com/github/Ryo-yuu/Demo/blob/main/DEA113.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/Ryo-yuu/Demo/refs/heads/main/exercise_data.csv'
#data = pd.read_csv('/content/sample_data/Custom_data/exercise_data.csv')
data = pd.read_csv(url)
data.head()
# Out:
#    Duration        Date  Pulse  Maxpulse  Calories
# 0        60  01-12-2020    110       130     409.1
# 1        60  02-12-2020    117       145     479.0
# 2        60  03-12-2020    103       135     340.0
# 3        45  04-12-2020    109       175     282.4
# 4        45  05-12-2020    117       148     406.0

# %%
#To read the last 5 rows
data.tail()
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 27        60  27-12-2020     92       118     241.0
# 28        60  28-12-2020    103       132       NaN
# 29        60  29-12-2020    100       132     280.0
# 30        60  30-12-2020    102       129     380.3
# 31        60  31-12-2020     92       115     243.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     object
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
data.describe()
# Out:
#          Duration       Pulse    Maxpulse    Calories
# count   32.000000   32.000000   32.000000   30.000000
# mean    68.437500  103.500000  128.500000  304.680000
# std     70.039591    7.832933   12.998759   66.003779
# min     30.000000   90.000000  101.000000  195.100000
# 25%     60.000000  100.000000  120.000000  250.700000
# 50%     60.000000  102.500000  127.500000  291.200000
# 75%     60.000000  106.500000  132.250000  343.975000
# max    450.000000  130.000000  175.000000  479.000000

# %% [markdown]
# Missing Value Analysis

# %%
data.isnull().sum()
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    2
# dtype: int64

# %%
#To get the percentage of null values in each colum
data.isnull().sum()/(len(data))*100
# Out:
# Duration    0.000
# Date        3.125
# Pulse       0.000
# Maxpulse    0.000
# Calories    6.250
# dtype: float64

# %%
#If we want to know the Rows and colums
data.shape
# Out:
# (32, 5)

# %% [markdown]
# Data reduction

# %%
#Removing the Pulse colum
#data = data.drop(['Pulse'], axis=1)

# %%
data.head()
# Out:
#    Duration        Date  Maxpulse  Calories
# 0        60  01-12-2020       130     409.1
# 1        60  02-12-2020       145     479.0
# 2        60  03-12-2020       135     340.0
# 3        45  04-12-2020       175     282.4
# 4        45  05-12-2020       148     406.0

# %%
data.shape
# Out:
# (32, 4)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Working with Date & Time

# %%
from datetime import date
print(date.today().year)
print(date.today().month)
print(date.today())
#Is it 23 Jan today Giving us date time in UTC Time
# Out:
# 2025
# 1
# 2025-01-23

# %%
from datetime import datetime
current_time = datetime.now()
print(current_time)

print("current_time:", current_time.strftime("%H:%M:%S"))
# Out:
# 2025-01-23 01:55:43.192181
# current_time: 01:55:43

# %%
#Caluculate the difference between Pluse & Maxpulse and store int in a new column "DifferenceOfPulse"
data['DifferenceOfPulse'] = data['Maxpulse']-data['Pulse']
data.head()
# Out:
#    Duration        Date  Pulse  Maxpulse  Calories  DifferenceOfPulse
# 0        60  01-12-2020    110       130     409.1                 20
# 1        60  02-12-2020    117       145     479.0                 28
# 2        60  03-12-2020    103       135     340.0                 32
# 3        45  04-12-2020    109       175     282.4                 66
# 4        45  05-12-2020    117       148     406.0                 31

# %% [markdown]
# **[Handling missing values]Different ways of handling missing values:
#
# 1. Mean
# 2. Mode
# 3. Median
# 4. Drop those rows

# %%
data.head(20)
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories  DifferenceOfPulse
# 0         60  01-12-2020    110       130     409.1                 20
# 1         60  02-12-2020    117       145     479.0                 28
# 2         60  03-12-2020    103       135     340.0                 32
# 3         45  04-12-2020    109       175     282.4                 66
# 4         45  05-12-2020    117       148     406.0                 31
# 5         60  06-12-2020    102       127     300.0                 25
# 6         60  07-12-2020    110       136     374.0                 26
# 7        450  08-12-2020    104       134     253.3                 30
# 8         30  09-12-2020    109       133     195.1                 24
# 9         60  10-12-2020     98       124     269.0                 26
# 10        60  11-12-2020    103       147     329.3                 44
# 11        60  12-12-2020    100       120     250.7                 20
# ...

# %%
data ['Calories']=data['Calories'].fillna(data['Calories'].mean())

# %%
data.head(20)
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories  DifferenceOfPulse
# 0         60  01-12-2020    110       130    409.10                 20
# 1         60  02-12-2020    117       145    479.00                 28
# 2         60  03-12-2020    103       135    340.00                 32
# 3         45  04-12-2020    109       175    282.40                 66
# 4         45  05-12-2020    117       148    406.00                 31
# 5         60  06-12-2020    102       127    300.00                 25
# 6         60  07-12-2020    110       136    374.00                 26
# 7        450  08-12-2020    104       134    253.30                 30
# 8         30  09-12-2020    109       133    195.10                 24
# 9         60  10-12-2020     98       124    269.00                 26
# 10        60  11-12-2020    103       147    329.30                 44
# 11        60  12-12-2020    100       120    250.70                 20
# ...

# %%
data ['Calories']=data['Calories'].fillna(data['Calories'].mean())
print("Mean of Maxpulse is:", data['Maxpulse'].mean())
print("Mean of Maxpulse is:", data['Maxpulse'].median())
print("Mean of Maxpulse is:", data['Maxpulse'].mode()[0])
#10,20,20,5,5

#Mean , Median, Mode of Calories:
# average(A10:A50)
# Out:
# Mean of Maxpulse is: 128.5
# Mean of Maxpulse is: 127.5
# Mean of Maxpulse is: 120

# %%
data.shape
# Out:
# (32, 6)

# %%
data_cleaned = data.dropna()
data_cleaned.shape
# Out:
# (31, 6)

# %%
data.isnull().sum()
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    2
# dtype: int64

# %%
data_cleaned = data.dropna()
#all the rows of all the column those contain null values

# %%
data.isnull().sum()
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    2
# dtype: int64

# %%
data_cleaned.shape
# Out:
# (29, 5)

# %%
data = data.dropna(subset=['Calories'])
#delete null rows from calories colum only
print(data.isnull().sum())
print(data.shape)
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64
# (30, 5)
